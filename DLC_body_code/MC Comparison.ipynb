# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %run -i '/home/ml/Documents/ladderwalk/postprocess.py'

# %%
# %run -i '/home/ml/Documents/ladderwalk/computation_and_comparison.py'
# Out:
# Score calculation and comparison done.... Starting on graphs
# All done

# %%
x = df['DLC_resnet101_LadderWalkFeb13shuffle1_1030000']["left fingers"]['x']
y = df['DLC_resnet101_LadderWalkFeb13shuffle1_1030000']["left fingers"]['y']
plt.plot(rung_x,func(rung_x,*np.polyfit(rung_x,rung_y,2)),label='rung curve fit')
plt.scatter(rung_x,rung_y,label='rung')
plt.scatter(x,y,label="forelimb location")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.gca().invert_yaxis()

# %%
x = df_wrist['x']
y = df_wrist['y']
base = func(x,*np.polyfit(rung_x,rung_y,2))
plt.plot(x,y,label='forelimb location',color='tab:orange',marker='o')
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.gca().invert_yaxis()

# %%
f
# Out:
# '/home/ml/Documents/Not_TADSS_Videos/MC45/cut/dlc_output_16-810/MC45_9-20-19_L2_crossing4_patternB_light2_DLC_resnet101_LadderWalkFeb13shuffle1_1030000.h5'

# %%
plt.plot(x,-1*np.gradient(x))

# %%
f
# Out:
# '/home/ml/Documents/Not_TADSS_Videos/MC61/cut/dlc_output_16-810/MC61_5-21-19_L3_crossing6_patternC_light1_DLC_resnet101_LadderWalkFeb13shuffle1_1030000.h5'

# %%
"/"+rung_folder+"/"+rung_file+"_"+"DLC_resnet50_LadderWalkMar12shuffle1_350000.h5"
# Out:
# '/home/ml/Documents/Not_TADSS_Videos/MC61/cut/dlc_output_rungs/MC61_5-21-19_L3_crossing6_patternC_light1_DLC_resnet50_LadderWalkMar12shuffle1_350000.h5'

# %%
rung_y
# Out:
# array([643.11557954, 644.95566217, 644.80041188, 645.98116644,
#        644.77879597, 647.38464776, 646.49511508, 647.27369021,
#        647.27154327, 648.9456745 , 648.84795301, 649.11164382,
#        648.48106542, 649.23975872, 650.05584927, 650.58244797,
#        650.86929637, 650.9449526 , 650.04327656, 652.24573596,
#        651.26751499, 652.25613509, 651.75450713, 651.45320656,
#        652.41646813, 652.05479799, 651.65856197, 651.6400841 ,
#        651.83158927, 649.72679927, 648.4231841 , 647.39945931,
#        645.32424927, 645.27767839, 644.93298235, 645.61687917,
#        640.33317776, 639.353684  , 637.14151317, 637.96550461,
#        636.15649309, 635.27566002, 635.28889834, 633.43080928,
#        632.17385233, 631.76543979, 629.61705806, 627.66009311,
#        626.65223641, 624.49231167, 623.15602085, 622.01294787,
#        621.18682125, 619.80653329, 617.65463678, 617.42213949,
#        616.21362199, 613.50225304, 613.02376793])

# %%
df_ankle['y'].mean()
# Out:
# -36.19546556806435

# %%
fingers_forward_list
# Out:
# [2.0, 11, 18.0]

# %%
(f.split("/")[8].split("_")[3])
# Out:
# 'crossing4'
