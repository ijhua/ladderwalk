# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %run -i '/home/ml/Documents/ladderwalk/postprocess.py'

# %%
# %run -i '/home/ml/Documents/ladderwalk/TADSS_counting.py'
# Out:
# MC71 2019-06-24 Y R4 4
# DoDB05 2019-02-01 Y L4 4
# DoDB05 2019-02-01 Y R1 1
# DoDB05 2018-11-28 N L3 1
# DoDB05 2019-02-01 N R1 1
# DoDB05 2019-01-03 N R4 1
# DoDB05 2018-11-30 N R4 1
# DoDB05 2018-11-02 N R4 1
# DoDB05 2019-01-02 N R2 1
# DoDB05 2018-11-30 N R4 1
# DoDB05 2018-12-31 Y L3 3
# DoDB05 2019-02-01 N R3 3
# DoDB05 2019-01-02 N R1 3
# DoDB05 2018-11-28 N L2 3
# DoDB05 2018-12-31 N R2 3
# DoDB05 2018-12-31 Y R1 1
# DoDB05 2019-02-01 N R3 1
# DoDB05 2018-11-02 N L1 1
# DoDB05 2019-01-04 N L2 1
# DoDB05 2019-02-01 N R2 1
# DoDB05 2019-01-02 Y R4 4
# DoDB05 2018-11-28 Y L2 2
# DoDB05 2019-02-01 N R3 2
# DoDB05 2019-02-01 N R2 2
# DoDB05 2018-11-02 Y L1 1
# DoDB05 2018-11-28 N L4 1
# DoDB05 2019-01-03 N R5 1
# DoDB05 2018-11-02 N L3 1
# DoDB05 2018-11-02 Y L1 1
# DoDB05 2019-02-01 N R2 1
# DoDB05 2019-01-03 N R4 1
# DoDB05 2018-11-26 N L3 1
# DoDB05 2018-11-28 N R3 1
# DoDB05 2018-11-30 N L4 1
# DoDB05 2018-12-31 N L2 1
# DoDB05 2018-11-30 N L4 1
# DoDB05 2018-11-28 N L1 1
# ...

# %%
print(subject,date,catch,run,crossing)
# Out:
# MC71 2019-05-23 00:00:00 Y L2 2

# %%
rung_file
# Out:
# 'DoDB05_2-1-19_L3_crossing5_patternA_light1'

# %%
f
# Out:
# '/media/ml/Data/TADSS/DoDB05/DoDB05_cut/dlc_output_2020-11-05/DoDB05_01.04.2019_R3_crossing6_patternA_light1_DLC_resnet50_LadderWalkFeb13shuffle1_450000.h5'

# %%
date
# Out:
# Timestamp('2019-05-23 00:00:00')

# %%
score_df= score_df.dropna()

# %%
score_df.to_csv("/home/ml/Documents/TADSS_Prelim_scores_5-11-2020.csv")
