# %%
import h5py
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import glob, os
import datetime as dt
import cv2
from scipy.signal import find_peaks, peak_prominences
import ffmpeg
import subprocess
import math

# %%
# %run -i '/home/ml/Documents/rung_functions.py'

# %%
# %run -i '/home/ml/Documents/mp_rung_scores.py'
# Out:
# /home/ml/Documents/mp_rung_scores.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   folders+=glob.glob("/home/ml/Documents/Not_TADSS_Videos/"+rat+"/cut/dlc_output_16-810/*.h5")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Documents/mp_rung_scores.py in <module>
#     101         total_steps_br = np.nan
#     102
# --> 103         y_pos_peaks_front,y_pos_peaks_back = find_slips()
#     104         slip_count_fl = len(y_pos_peaks_front)
#     105         slip_count_bl = len(y_pos_peaks_back)
#
# ~/Documents/mp_rung_scores.py in find_slips()
#
# ...

# %%
# %run -i '/home/ml/Documents/multipointgraphs.py'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Documents/multipointgraphs.py in <module>
#       1 calcs=[]
# ----> 2 score_df = score_df.dropna()
#       3
#       4 for index,row in score_df.iterrows():
#       5     subject = row['subject']
#
# NameError: name 'score_df' is not defined

# %%
find_peaks(df_fingers['y'],height=663)
# Out:
# (array([], dtype=int64), {'peak_heights': array([], dtype=float64)})

# %%
pd.read_hdf("/"+rung_folder+"/"+rung_file+"_"+"DLC_resnet50_LadderWalkMar12shuffle1_350000.h5")
# Out:
# scorer    DLC_resnet50_LadderWalkMar12shuffle1_350000                         \
# bodyparts                                      rung_1
# coords                                              x           y likelihood
# 0                                           96.297829  639.754517   0.054013
# 1                                           96.066071  640.359070   0.033941
# 2                                           95.649330  639.392090   0.042431
# 3                                           96.332382  639.284119   0.036062
# 4                                           96.938622  642.091309   0.047046
# 5                                           95.761444  639.375244   0.017936
# 6                                           95.550140  639.383972   0.022205
# 7                                           95.072746  639.308716   0.038417
# 8                                           95.064880  638.974182   0.032677
# ...

# %%
step_indexes = []
for x in df_fingers['x']:
    diff = abs(rung_x-x)
    ind = (np.where(diff<10))
    step_indexes.append(ind[0])
# Out:
# /home/ml/Documents/mp_rung_scores.py:4: RuntimeWarning: invalid value encountered in less
#   left_handed = []

# %%
step_indexes
# Out:
# [array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([37]),
#  array([35]),
#  array([35]),
#  array([35]),
#  array([31]),
#  array([31]),
#  array([31]),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([], dtype=int64),
#  array([ 0, 17, 18]),
#  array([ 0, 18]),
#  array([ 0, 17, 18])]

# %%
f
# Out:
# '/home/ml/Documents/Not_TADSS_Videos/MC45/cut/dlc_output_16-810/MC45_7-17-19_L4_crossing8_patternB_light1_DLC_resnet101_LadderWalkFeb13shuffle1_1030000.h5'
