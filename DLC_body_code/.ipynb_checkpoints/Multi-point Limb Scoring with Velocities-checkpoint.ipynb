# %%
import h5py
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import glob, os
import datetime as dt
import cv2
from scipy.signal import find_peaks, peak_prominences
import ffmpeg
import subprocess
import math

# %%
# %run -i '/home/ml/Documents/functions.py'

# %%
# %run -i '/home/ml/Documents/mplimbscore.py'
# Out:
# /home/ml/Documents/mplimbscore.py:34: RuntimeWarning: invalid value encountered in less_equal
#   #frontleft
# /home/ml/Documents/mplimbscore.py:34: RuntimeWarning: invalid value encountered in greater_equal
#   #frontleft
# /home/ml/anaconda3/lib/python3.7/site-packages/scipy/signal/_peak_finding.py:633: RuntimeWarning: invalid value encountered in greater_equal
#   keep &= (pmin <= peak_properties)

# %%
score_df
# Out:
#     Subject      Date Run Crossing  Front Right Steps  Front Right Hits  \
# 0      MC45   7-17-19  L4        8                NaN               NaN
# 1      MC45   9-20-19  L4        8                NaN               NaN
# 2      MC45   7-16-19  L3        6                NaN               NaN
# 3      MC45   7-15-19  R3        5                6.0               6.0
# 4      MC45  09-16-19  L2        4                NaN               NaN
# ..      ...       ...  ..      ...                ...               ...
# 273    MC70   3-14-19  R4        7                6.0               6.0
# 274    MC70   3-12-19  L1        2                NaN               NaN
# 275    MC70   4-11-19  R5        9                8.0               7.0
# 276    MC70   3-11-19  R1        1                6.0               6.0
# 277    MC70   3-12-19  L3        6                NaN               NaN
#
#      Front Right Misses  Front Left Steps  Front Left Hits  Front Left Misses  \
# 0                   NaN               2.0              2.0                0.0
# 1                   NaN               9.0              9.0                0.0
# 2                   NaN               6.0              6.0                0.0
# 3                   0.0               NaN              NaN                NaN
# 4                   NaN              10.0             10.0                0.0
# ..                  ...               ...              ...                ...
# 273                 0.0               NaN              NaN                NaN
# 274                 NaN               7.0              7.0                0.0
# 275                 1.0               NaN              NaN                NaN
# 276                 0.0               NaN              NaN                NaN
# 277                 NaN               9.0              9.0                0.0
#
#      Back Right Steps  Back Right Hits  Back Right Misses  Back Left Steps  \
# 0                 NaN              NaN                NaN              5.0
# 1                 NaN              NaN                NaN              8.0
# 2                 NaN              NaN                NaN              7.0
# 3                 6.0              6.0                0.0              NaN
# 4                 NaN              NaN                NaN              8.0
# ..                ...              ...                ...              ...
# 273               6.0              6.0                0.0              NaN
# 274               NaN              NaN                NaN              5.0
# 275               9.0              8.0                1.0              NaN
# 276               6.0              6.0                0.0              NaN
# 277               NaN              NaN                NaN             10.0
#
#      Back Left Hits  Back Left Misses  Front Y Threshold  Back Y Threshold
# 0               5.0               0.0         656.814941        649.379272
# 1               8.0               0.0         652.107117        652.714050
# 2               7.0               0.0         707.950256        704.113586
# 3               NaN               NaN         608.462463        631.820984
# 4               8.0               0.0         651.380005        657.314819
# ..              ...               ...                ...               ...
# 273             NaN               NaN         593.317261        577.918396
# 274             5.0               0.0         677.658386        664.968750
# 275             NaN               NaN         529.930420        530.769348
# 276             NaN               NaN         681.623596        667.132812
# 277            10.0               0.0         660.694641        664.477783
#
# [278 rows x 18 columns]

# %%
name.split("_")[3][-1]
# Out:
# '6'
