# %%
import h5py
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import glob, os
import datetime as dt
import cv2
from scipy.signal import find_peaks, peak_prominences
import ffmpeg
import subprocess
import math

# %%
def likelihood_filter(df,threshold):
    df.loc[df['likelihood']<=threshold] = np.nan
    df2 = df
    df2 = df2.ffill()
    df2 = df2.reset_index(drop=True)
    return df2

# %%
# read the file
rats = ["MC45","MC61","MC78","MC87","MC30","MC70"]
right_handed = ["MC45","MC61","MC78","MC87","MC30","MC70"]
left_handed = []
folders = []
for rat in rats:
    folders+=glob.glob("/home/ml/Documents/Not_TADSS_Videos/"+rat+"/cut/dlc_output_16-810/*.h5")

scores = []
score_cols = ["subject", "date", "run", "crossing","limb","comp_hits","comp_misses","comp_steps"]
for f in folders:
    df = pd.read_hdf(f)
    name=f.split("/")[8]
    run = name.split("_")[2]
    subject = name.split("_")[0]
    date = name.split("_")[1]
    crossing=name.split("_")[3][-1]
    likelihood_threshold = 0.1
    xheight = 25
    xdist = 5
    yheight = 5
    ydist = 4
    path = f.split(".")[0].split("/")[:-2]+["dlc_output_rungs"]
    rung_folder = os.path.join(*(path))
    rung_file= f.split(".")[0].split("/")[-1].split("_")[0]+"_"+f.split(".")[0].split("/")[-1].split("_")[1]+"_"+f.split(".")[0].split("/")[-1].split("_")[2]+"_"+f.split(".")[0].split("/")[-1].split("_")[3]+"_"+f.split(".")[0].split("/")[-1].split("_")[4]+"_"+f.split(".")[0].split("/")[-1].split("_")[5]
    rung_df = pd.read_hdf("/"+rung_folder+"/"+rung_file+"_"+"DLC_resnet50_LadderWalkMar12shuffle1_350000.h5")
    rung_df = rung_df['DLC_resnet50_LadderWalkMar12shuffle1_350000']
    rung_list = []
    for i in range(1,63):
        rung_list.append("rung_"+str(i))
    for rung in rung_list:
        rung_df[rung]=likelihood_filter(rung_df[rung],0.8)
    rung_mean = rung_df.agg(["mean"])
# Out:
# /home/ml/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-0ef846869a7d> in <module>
#      24     rung_folder = os.path.join(*(path))
#      25     rung_file= f.split(".")[0].split("/")[-1].split("_")[0]+"_"+f.split(".")[0].split("/")[-1].split("_")[1]+"_"+f.split(".")[0].split("/")[-1].split("_")[2]+"_"+f.split(".")[0].split("/")[-1].split("_")[3]+"_"+f.split(".")[0].split("/")[-1].split("_")[4]+"_"+f.split(".")[0].split("/")[-1].split("_")[5]
# ---> 26     rung_df = pd.read_hdf("/"+rung_folder+"/"+rung_file+"_"+"DLC_resnet50_LadderWalkMar12shuffle1_350000.h5")
#      27     rung_df = rung_df['DLC_resnet50_LadderWalkMar12shuffle1_350000']
#      28     rung_list = []
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/pytables.py in read_hdf(path_or_buf, key, mode, **kwargs)
#     379         if not exists:
#     380             raise FileNotFoundError(
# --> 381                 "File {path} does not exist".format(path=path_or_buf)
#     382             )
#     383
#
# FileNotFoundError: File /home/ml/Documents/Not_TADSS_Videos/MC45/cut/dlc_output_rungs/MC45_7-16-19_L2_crossing4_patternB_light1_DLC_resnet50_LadderWalkMar12shuffle1_350000.h5 does not exist

# %%
likelihood_filter(rung_df["rung_33"],0.8)
# Out:
# /home/ml/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# coords           x           y  likelihood
# 0       953.979248  655.740540    0.971642
# 1       954.317383  655.860168    0.965146
# 2       954.838623  655.825562    0.966193
# 3       954.111389  655.764526    0.938979
# 4       955.056274  655.664551    0.964999
# 5       955.216675  654.231689    0.969435
# 6       954.626892  655.979553    0.946615
# 7       954.402649  656.041321    0.888335
# 8       954.045776  655.690552    0.966716
# 9       956.016235  651.245789    0.971726
# 10      957.241943  654.503845    0.935806
# 11      956.492249  653.801941    0.982477
# 12      954.595337  655.287964    0.952606
# 13      954.362061  655.613770    0.952208
# 14      955.025024  655.306091    0.969389
# 15      954.481323  655.597351    0.962295
# 16      954.665527  655.430298    0.965527
