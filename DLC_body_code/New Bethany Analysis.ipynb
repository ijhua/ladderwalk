# %%
import h5py
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import glob, os
import datetime as dt
import cv2
from scipy.signal import find_peaks, peak_prominences
import ffmpeg
import subprocess

# %%
# %run -i '/home/ml/Documents/functions.py'

# %%
# %run -i '/home/ml/Documents/bethany_multipoint_scoring.py'
# Out:
# /home/ml/Documents/bethany_multipoint_scoring.py:34: RuntimeWarning: invalid value encountered in less_equal
#   #back left
# /home/ml/Documents/bethany_multipoint_scoring.py:34: RuntimeWarning: invalid value encountered in greater_equal
#   #back left

# %%
df_new
# Out:
#    week               limb comp_score           dlc_score            \
#                                  mean       sem      mean       sem
# 0  -2.0      Dominant Back   0.019841  0.013974  0.036925  0.015882
# 1  -2.0     Dominant Front   0.046429  0.020802  0.057239  0.016019
# 2  -2.0   Nondominant Back   0.032729  0.022117  0.020086  0.009570
# 3  -2.0  Nondominant Front   0.058826  0.028828  0.054446  0.018394
# 4  -1.0      Dominant Back   0.000000  0.000000  0.000000  0.000000
# 5  -1.0     Dominant Front   0.035714  0.035714  0.063492  0.037226
# 6  -1.0   Nondominant Back   0.083333  0.083333  0.035714  0.035714
# 7  -1.0  Nondominant Front   0.025000  0.025000  0.074811  0.026532
# 10  3.0   Nondominant Back   0.053875  0.015360  0.036875  0.010112
# 11  3.0  Nondominant Front   0.045525  0.012383  0.034691  0.010487
# 8   3.0      Dominant Back   0.040097  0.010213  0.041911  0.009093
# 9   3.0     Dominant Front   0.024056  0.008409  0.064941  0.014119
# ...
